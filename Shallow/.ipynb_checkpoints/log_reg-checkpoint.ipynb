# %% [markdown]
# # Logistic Regression
#
# - __Model info:__
#     - features:
#     - model:
#     - acc:
#
# https://www.cs.uic.edu/~liub/FBS/sentiment-analysis.html

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, HashingVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import matthews_corrcoef
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier


from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer, WordNetLemmatizer

# %%
#nltk.download(['stopwords'])

# %%
tweets_DF = pd.read_csv('../Dataset-OLID/OLIDv1.0/data_subtask_a.csv')
tweets_DF.head(10)
# Out:
#    Unnamed: 0     id                                              tweet  \
# 0           0  86426  @USER She should ask a few native Americans wh...
# 1           1  90194  @USER @USER Go home you’re drunk!!! @USER #MAG...
# 2           2  16820  Amazon is investigating Chinese employees who ...
# 3           3  62688  @USER Someone should'veTaken" this piece of sh...
# 4           4  43605  @USER @USER Obama wanted liberals &amp; illega...
# 5           5  97670                  @USER Liberals are all Kookoo !!!
# 6           6  77444                   @USER @USER Oh noes! Tough shit.
# 7           7  52415  @USER was literally just talking about this lo...
# 8           8  45157                         @USER Buy more icecream!!!
# 9           9  13384  @USER Canada doesn’t need another CUCK! We alr...
#
#   subtask_a  label_a
# 0       OFF        1
# 1       OFF        1
# 2       NOT        0
# 3       OFF        1
# 4       NOT        0
# 5       OFF        1
# 6       OFF        1
# 7       OFF        1
# 8       NOT        0
# 9       OFF        1

# %% [markdown]
# ## 1. Preprocessing

# %%
import nltk
from nltk import word_tokenize
from nltk import ngrams

'''
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import WordPunctTokenizer
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
'''
# Out:
# '\nfrom nltk.corpus import stopwords\nfrom nltk.stem import PorterStemmer\nfrom nltk.tokenize import WordPunctTokenizer\nfrom nltk.collocations import BigramCollocationFinder\nfrom nltk.metrics import BigramAssocMeasures\n'

# %%
# remove unnecessery columns
tweets_DF = tweets_DF.rename(columns = {'label_a':'label'})
tweets_DF = tweets_DF.drop(["Unnamed: 0", "id", "subtask_a"], axis=1)

# %% [markdown]
# -----------------
#
# Removing @USER

# %%
import re

# %%
REMOVE_USER = re.compile("@USER")

def remove_user(tweet):
    return REMOVE_USER.sub("", tweet)

# %%
tweets_DF['tweet'] = tweets_DF['tweet'].apply(remove_user)

# %% [markdown]
# -------------------------------
# Extracting emoji

# %%
import emoji
import regex

# %%
def split_count(text):
    emoji_list = []
    data = regex.findall(r'\X', text)
    for word in data:
        if any(char in emoji.UNICODE_EMOJI for char in word):
            emoji_list.append(word)

    return emoji_list

# %%
tweets_DF['emoji'] = tweets_DF['tweet'].apply(split_count)

# %% [markdown]
# ----------------------

# %% [markdown]
# ### B) Sentiment

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
analyser = SentimentIntensityAnalyzer()

def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    return [score['neg'], score['neu'], score['pos'], score['compound']]

# %%
tweets_DF['sentiment'] = tweets_DF['tweet'].apply(sentiment_analyzer_scores)
tweets_DF['negative_sentiment'] = tweets_DF['sentiment'].apply(lambda row: row[0])
tweets_DF['neutral_sentiment'] = tweets_DF['sentiment'].apply(lambda row: row[1])
tweets_DF['positive_sentiment'] = tweets_DF['sentiment'].apply(lambda row: row[2])
tweets_DF['compound'] = tweets_DF['sentiment'].apply(lambda row: row[3])

tweets_DF = tweets_DF.drop(["sentiment"], axis=1)

# %% [markdown]
# -------------------------------
# ### C) Negative words

# %%
from nltk import word_tokenize

# %%
negative_words_file = open("negative-words.txt")
negative_words = []

for line in negative_words_file:
    if not str.startswith(line, ";"):
        negative_words.append(line.split("\n")[0])
        
negative_words = negative_words[1:]

# %%
def check_for_negative_words(tweet):
    tweet = str.lower(tweet)
    words = word_tokenize(tweet)
    if any(word in negative_words for word in words):
        return True
    return False

# %%
tweets_DF['negative_words'] = tweets_DF['tweet'].apply(check_for_negative_words)

# %% [markdown]
# ----------------------------
# ### D) Removing stopwords, lemmatization

# %%
english_stop_words = stopwords.words('english')

# %%
lemmatizer = WordNetLemmatizer() #SnowballStemmer('english')
   
def preprocess_tweet(tweet):
    #remove all non letters
    regex = re.compile('[^a-zA-Z]')
    removed_nonalphanumeric = regex.sub(' ', tweet)
    lowercased_tweet = str.lower(removed_nonalphanumeric)

    #remove stopwords
    without_stopwords = " ".join(word if word not in english_stop_words else "" for word in lowercased_tweet.split())
    
    #lemmatization
    lemmatized = ' '.join([lemmatizer.lemmatize(word) for word in without_stopwords.split()])
    return lemmatized

# %%
tweet = tweets_DF['tweet'][2]
print(tweet, "\n")
preprocess_tweet(tweet)
# Out:
# Amazon is investigating Chinese employees who are selling internal data to third-party sellers looking for an edge in the competitive marketplace. URL #Amazon #MAGA #KAG #CHINA #TCOT
# 'amazon is investigating chinese employee who are selling internal data to third party seller looking for an edge in the competitive marketplace url amazon maga kag china tcot'

# %%
tweets_DF['clean_tweet_with_stopwords'] = tweets_DF['tweet'].apply(preprocess_tweet)

# %% [markdown]
# ### E) Word embeddings

# %%
from gensim.models import KeyedVectors
from gensim.test.utils import common_texts, get_tmpfile

# %%
corpus = tweets_DF['clean_tweet_with_stopwords'].values

# we need to pass splitted sentences to the model
tokenized_sentences = [sentence.split() for sentence in corpus]
model = word2vec.Word2Vec(tokenized_sentences, min_count=1)
model.save("word2vec.model")

# %%
model = word2vec.Word2Vec.load("word2vec.model")
#model.train([["hello", "world"]], total_examples=1, epochs=1)

# %%
model.vocabulary

# %%
vector = model.wv['trump']
def embedd(sentance):
    tokens = sentance.split()
    summed_embedding = np.zeros(100)
    for token in tokens:
        summed_embedding += model.wv[token]
        
        
    return summed_embedding/len(tokens)

# %%
tweets_DF['embedding'] = tweets_DF['clean_tweet_with_stopwords'].apply(embedd)

# %% [markdown]
# ## 2. Models
# ------------------------------------
#
# ### 2.1 Model: sentiment

# %%
#creating train, test 
sentiment = tweets_DF[["negative_sentiment","neutral_sentiment", "positive_sentiment", "negative_words"]].values
y = tweets_DF['label'].values

X_train_sentiment, X_test_sentiment, y_train_sentiment, y_test_sentiment = train_test_split(sentiment, y, test_size=0.25, random_state=1000)

# %%
classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train_sentiment, y_train_sentiment)
score = classifier.score(X_test_sentiment, y_test_sentiment)

print("Accuracy:", score)
# Out:
# Accuracy: 0.7090634441087613

# %% [markdown]
# ### 2.2 Model : tf_idf

# %%
tweets = tweets_DF['tweet'].values
y = tweets_DF['label'].values

vectorizer = TfidfVectorizer()
vectorizer.fit(tweets)

tweets_train, tweets_test, y_train, y_test = train_test_split(tweets, y, test_size=0.25, random_state=1000)

X_train_tfidf = vectorizer.transform(tweets_train)
X_test_tfidf  = vectorizer.transform(tweets_test)

# %%
classifier_tfidf = LogisticRegression(max_iter=100)
classifier_tfidf.fit(X_train_tfidf, y_train)
score = classifier_tfidf.score(X_test_tfidf, y_test)

print("Accuracy:", score)
# Out:
# Accuracy: 0.7537764350453172

# %% [markdown]
# ### 2.3 Model: count_vector, clean data
# - Old data voc size: 19083
# - New data voc size: 16622

# %%
tweets = tweets_DF['clean_tweet'].values
y = tweets_DF['label'].values

vectorizer = CountVectorizer(binary=True,  ngram_range=(1, 3))
vectorizer.fit(tweets)

tweets_train, tweets_test, y_train, y_test = train_test_split(tweets, y, test_size=0.25, random_state=1000)

X_train_clean = vectorizer.transform(tweets_train)
X_test_clean  = vectorizer.transform(tweets_test)

# %%
classifier_clean = LogisticRegression()
classifier_clean.fit(X_train_clean, y_train)
score = classifier_clean.score(X_test_clean, y_test)

print("Accuracy:", score)
# Out:
# Accuracy: 0.7773413897280966

# %%
X_train_clean = vectorizer.transform(tweets[:9000])
X_test_clean  = vectorizer.transform(tweets[9000:])
y_train = y[:9000]
y_test = y[9000:]

classifier_clean = LogisticRegression(max_iter=1000)
classifier_clean.fit(X_train_clean, y_train)
score = classifier_clean.score(X_test_clean, y_test)

print("Accuracy:", score)

# %% [markdown]
# Failed to predicit:

# %%
prediction = classifier_clean.predict(X_test_clean)
z = zip(prediction, y_test, range(9000, 9000+len(prediction)))
indices = np.array([i if p1!=p2 else -1 for p1, p2, i in z ])
indices = indices[indices>0]
for i in indices:
    print(tweets_DF['label'][i],tweets_DF['tweet'][i],  "\n")
# Out:
# 0      I'm sure most patients would prefer to be treated in a professional and transparent manner by the NHS rather than being packed off to some carpet bagging health company hoping to squeeze a shareholder dividend out of an essential public service monopoly.
#
# 0   They probably get bonus pay for that
#
# 0   I don’t think she needed any money to do this. I think she is so left wing that she thinks she is Joan of Arc. Now we have Spartacus and Joan....who’s next on the agenda?
#
# 0 ...or the many other instances where AR-15s used for home defense are labeled mass shootings" by gun control:  URL
#
# 0     Be smarter- Congress legislates. We need congress with better skill stacks to solve. Dr Shiva has incredible proposal.  If u can stop long enough to learn.  URL
#
# 0  He is quite the yarn spinner
#
# 0  I hope you're also spending energy focusing on #antifa and the endless attacks on conservative citizens, cops, journalists, their destruction of property and the strange phenominon of journalists" ignoring them?  Just kidding. Not like you're a real journalist/documentarian."
#
# 0  Liberals are against abortion too: we call it birth control.""
#
# 0   the USA is NOT a democracy. The USA is a constitutional republic!  Take a civics class!
#
# 1  He really bisca fool huh
#
# 1   OurCountry is being saved from evil slugs like Hillary Clinton.  The Deep State is going down and I personally can't wait for Hillary to be brought in front of a Military Tribunal.  The penalty for treason is death I believe.
#
#
# 0   Vinnie’s gonna hunt me down at an antifa march.  Shouldn’t be hard to recognise me  😂
#
# 0    So the only difference affecting crime rates between HI and CONUS is gun control?
#
# 1  She is a complete idiot
#
# 0  Strange how Gun Control never works Criminals will never obey laws I am my own #FirstResponder URL
#
# 0           Good vibes going towards Robert!!!
#
# 0  BO is bitterly PO’d that Donald Trumps presidency has made him look like the bad president that he was.
#
# 0  What??? She is cute but she doesn't look like me at all
#
# 1    You think it's just antifa who stands up against fascists? All decent people will. Look through history. The flabby bigots will run with their tails between their legs like that always do.
#
# 0  You don't need makeup bc you are beautiful asf angel💗💗💗💗 love u
#
# 0   Cruz needs to add #ANTIFA to this proposed Act. That way we literally kill #2BirdsOfAFeather with one stone.
#
# 1  I hope it shows how to plug a bullet hole? People are getting fed up with mommy warriors and bad things are going to happen to Antifa soon if they are not reigned in
#
# 0                                     Nope.
#
# 1 *pats tears* Gosh..... Dammit *sniffs* *sighs* My baby-* sniffs* She just doesn't deserve this💔😭. She is so precious and I- URL
#
# 1  When do you post on conservatives declaring Ford a liar without evidence? URL
#
# 0  dallon you just said lit i'm sorry sweetie but you are cancelled
#
# 0    2bn is notong term that shud b annually.
#
# 0 #TwitterShouldBe a place where everyone can have a voice- including conservatives. Less shadow-banning and throttling of conservative accounts - #FreedomOfSpeech  #Throwback #BenGarrison #cartoon  URL URL
#
# 0  That image tells the story of generations of people self medicating to manage distress. Can't count the number of people lost and like you say too many can't see beyond the sickening labels.
#
# 0   looking forward to meeting you at conference!
#
# 0   63 million Americans understand embarrassed... we dealt with watching our country being divided by progressive ideologies for 8 years ruled by entitled and elitist liberals! Yep.... URL
#
# 0  you are holding my life hostage! I have tried everything you have asked to get the freeze removed and for weeks you have done nothing to make this happen.  and  made it easy. None of your antiquated systems work and customer service is non-existent.
#
# 0  this high road shit doesn't work on Trump/Conservatives/Republicans/GOP/MAGAts no more mister nice guy. As  says they go low we go for the jugular. They have to be stopped.
#
# 1   Unfortunately gun control is long game and the house always wins.
#
# 1  Climbs up the charts in Christian Music...only to wither as a fig on a tree as a false prophet. That is
#
# 1  sick of white neo liberals speaking for Black people saying they all love Hillary. They are so deluded. It’s like they just rep ‘black lives matter’ so they can appear woke enough to keep railing against Bernie supporters. Because you know they didn’t care b4 Hillary lost 2 trump
#
# 0   No Fans Left.
#
# 1   LMAOOO fucking love you see you hotties soon xox
#
# 1      He lost his virginity This process has been turned into a clown show Protestors democrats paid for was unethical There hate shows in everyway TRUMP denounced Natzi group  and bad on both sides which is true But democrats refuse to denounce Antifa a democratic domestic terror-
#
# 0     And you say liberals make false promises? How’s that wall coming? How’s that denuclearization of NK coming? How that “tax break” working out for you? Nice ole tariffs we got there huh? But yea keep on saying wild outlandish shit to make you feel better
#
# 0  What she really means is for the rest of America to shut up and take all the hate that  White Christian Conservatives give out and never fight back
#
# 0                 Woke Bible Readings from Midwest Antifa.
#
# 0  Enjoy them before those liberals take them white boys down for being white !
#
# 0   Ah he is great. Cheers
#
# 0  So you are saying they should not count on him to keep the streak alive?
#
# 1  Fool!
#
# 1                           I never talked about gun control in any form.
#
# 0   You are so right
#
# 1  How? You can’t just say “Wrong” with no evidence for why it is. You said you agree with Sargon I’m pretty much every subject but gun control and healthcare. That’s not what a centrist believes.
#
# 0   Absolutely love Serena....however - the way she behaved was totally on her and the ref was within his rights...she is deflecting here by making it about women’s rights....
#
# 0  Trust me.. i know her well enough so that she is ok if i take a body of another good girl for the night.""
#
# 0  I wouldn't say I'm conflicted - Article 7 would be justified - but you are right in stating that the really important decision will be taken (or postponed) inside the  The Sargentini report was but a prelude. Those who want #Orban out should now push harder.
#
# 0  You are an individual of excellent taste.
#
# 0   Has to be MK ultra.
#
# 1 #Police? #Banter Training?  Oh my God! Fools and Tools.  #MAGA #MEGA #MBGA #MCGA #Conservatives #Patriots URL
#
# 0  Her last name says a lot MESS!
#
# 1  You are sexy as fuck babygirl🔥🔥🔥
#
# 0   Globalization threatens nationality causing the alt right  concerns about destroyed values that keep us unified like the ten commandments and the Constitution. Then we have the alt left demanding their mini Bolshevik indoctrination to oppress everyone and start a war. Let God be
#
# 1  You are fake news
#
# 0      Unfortunately some democrats and their supporters have shown support for antifa and lied by saying they were protesting peacefully
#
# 0 1. We all want affordable health care for everyone. Liberals want it so badly they are willing to change the facts to produce the theory. That's false science. The correct thing is to change the theory to accommodate the facts. That's science.
#
# 0   you are that special case that gets away with introducing an innocent child(you own) to hate. bravo
#
# 0  And no one cares
#
# 0  If there are any infractions due to pot the liberals should be sued.
#
# 1  Liberal Dictionary: -Illegal Immigrants: Dreamers -Trump Supporters: Deplorable -MS-13 Killers: Human Beings -Human Beings in the Womb: Not Human Beings -Antifa: Protestors -Law Abiding NRA Members: Terrorists -Bill Clinton: Feminist -Brett Kavanaugh: Predator
#
# 0 91.3FM The Edge is playing What You Are" by Audioslave."
#
# 0  imagine unironically believing that liberals support antifa
#
# 0  Tim Kaine Completely SILENT. #HimToo #vasen #ViolentLeft #antifa #muslim #virginia URL
#
# 0 *shuving tide pods in mouth* need more gun control nomnom nom nom
#
# 1  He is way more creepier and says way more stupid things URL
#
# 0   What type of common sense gun control ideas would you propose?
#
# 0  I MISS U
#
# 0   Sshh 🙊 she is lying😏😅😭😂
#
# 0 #PresidentTrump was elected because we are so very tired of destructive #Dems! We're look for strong conservatives like #TreyGowdy. URL
#
# 0     Antifa is banned by the central commitee for they are not proper socialists. More pinko then red.
#
# 0   His staffers should remember that Trump is in favor of using enhanced interrogation techniques.
#
# 0               Followed all patriots that I wasn't already following 😃 pls follow back! Thanks  for a great list of Trumpsters! MAGA! #PatriotsUnite
#
# 1  He is a cancer though. Suspended for like 3 years and then is late to practice when he’s able to play again. Can you blame them for cutting him when they suck anyways?
#
# 0  And Democrats want an open border and gun control...🤣🤣😅
#
# 0   But Google can give Beijing every Americans phone number. You’re kidding me right?   MAGA 2020
#
# 0  What about  ?  You and your antifa son are keeping your trap shut about that.
# 1 No. I respect him for sticking up for his wife but let's not forget that he's running around screaming MAGA &amp; said slavery sounds like an option to him. URL
#
# 1  Patrick ass??
#
# 1   It's clear that Trump is President and hillary still can't accept that. Too bad 'ause he's there for 6 more years. #MAGA
#
# 1  Doing soooo much better than the big Zero and his losers
#
# 0  She is so beautiful! 😍😍😍
#
# 1    reckon he is upset about Wacky Wednesdays because the boys told him it was absolutely going to be a Mad Monday this time?
#
# 0     FBI and Doj lawless? Why so many guilty pleas and cooperation? Sure is strange all of trumps campaign is going down in a first ball of flames yet conservatives still fail to admit the unprecedented level of corruption by GOP and make the needed corrections. Sad
#
# 1  Get away from these lying toxic people!
#
# 0        I cited the Constitution. That’s not good enough for you?
#
# 1  Biggest corrupt lying piece of  s***💩 there ever was!
#
# 0   George Soros Antifa People ! URL
#
# 0  Who needs courts when you have clairvoyant liberals.
#
# 1        This women is a vile example of the far left lunacy. She is using the Alinsky, Rules for Radicals Handbook." No matter what u have to do, (lie,steal,use violence etc. )u must destroy the conservatives. They lack character &amp; have no moral code."
#
# 1     You are two nutcases. Obviously. URL
#
# 0   Bad bytches prolly got some fucked up attitudes! So this oughta y’all y’all ya looks only carry you so far 🤷🏾‍♂️
#
# 0      Antifa is always igniting fighting and violence with the right, therefore they are YOU! BLM is mostly" peaceful? Are you kidding me? Do your research! Geez URL
#
# 0    you are an amazing genius
#
# 0   You said gun safety laws. Funny. You mean gun control agenda.  Your staffers must be editing your shit these days. Kudos to the minions.
#
# 1  Fake News
#
# 0                This is the VetsResistSquadron" is Bullshit.. They are girl scout veterans, I have never met any other veterans or served with anyone that was a gun control advocate? Have you?"
#
# 0  Because they’re so hateful and can’t cover anything except Trump.  I remember when Wolf and Anderson were actually decent journalists.....
#
# 1 #KavanaughConfirmationHearings Crazy Dick Durbin using the confirmation hearings to try and push gun control. He is using this hearing to make speeches and push an agenda. The whole thing has been a circus of Democrats pushing an agenda while vowing to vote no on confirmation.
#
# 0              Yeah most Antifa are Americans and still they advocate for an ideology that will destroy our great country. That makes them traitors and should be treated as such.
#
# 0  Seriously you are the best
#
# 0    Thank you for your conscience and actions.
#
# 0  Why does it matter if a candidate is a woman or a man? I thought we were all the same? Everything the liberals believe in contradicts their other beliefs 😂
#
# 0  No we no mames
#
# 0  Your article on Clay Travis Politics in Sports " is the same old ANTIFA-LIKE RANT"
#
# 1  👌🏻 I’ve never seen anyone talk like that on Twitter before and I’ve seen some really messed up shit
#
# 1  Clearly it does bc the cheerleader is smaller than the other girl and she whooped that ass after being slammed to the ground and everything
#
# 1 @ everyone who said jihoons new hair cut is ugly: you are wrong
#
# 1  Coming from one of the most corrupt AG’s!
#
# 0    Plus now we know where she likes to kiss you at when she is singing Don’t Judge Me.
#
# 1    Yeah  probably views groups like Antifa and EFF as moderates. People who are against farm murders are labeled just as extreme as people singing songs about actually killing those farmers. Crazy times we live in.
#
# 1   Literally.  You are literally a crazy person.
#
# 1   Rescue conservatives from its own demons? Who are the two or three most notorious serial abusers of women in the last 30 years? Hint: they were not GOP. Did they ever face consequences?
#
# 1      Now I know you're having a laugh. Do you really believe that the media aren't picking on him? As for getting his shit together", what "shit" would that be?"
#
# 0 #IronicNews: #Conservatives who complain #Liberals go #PantsOnFire about #TrumpPocalypse am now #mad at #Obama for something him NOT said.
#
# 0  HE SAID HE IS THRILLED TO BE A PART OF THE  OWNERSHIP GROUP!
#
# 0  I seems Hannity has been a client of the Bunny Bar (at the Bunny Ranch) for years (30+). He (allegedly) recruits Fox ‘talent’ and guest speakers from there. URL
#
# 0  Do you support our POTUS? (Please help by retweeting and following after voting!)  Long live USA😍 #MAGA
#
# 0  Always allege that she is a poor girl and with tenacity and efforts win over this position for future congresswoman ...if she win.
#
# 1  you live in the big dick part cause your gay
#
# 0  Evil
#
# 1  #Trump gifted the 1% with #GOPTaxScam the biggest wealth grab in modern history URL yet #trump supporter #dopes prefer to vote against their best interests so perhaps you cannot fix stupid!  #MAGA🇺🇸
#
# 0  You are a genuinely cool dude.
#
# 0  Didn’t a woman beat her? Huh...
#
# 0  It's the ANTIFA gang!
#
# 0  He should have tried that on obama after he gpsent millions to Iran which has been traced to terrorists! Unbelievable
#
# 0  Well you are dumped
#
# 0    She is clothed with strength and dignity and laughs without fear of the future. Proverbs 31:25 💕
#
# 1  Lmao I have it too. Shitty quality but I don’t mind it either. The lowlands one sounds better 👍🏻
#
# 0     How so?
#
# 1  #IWillNotSubmit to Accuser Leftist Liberals DemonRats Plantations Mind Control Agenda! Globalist puppet! #MeToo Movement Hollyweird #SnowFlakes #Pedowood was SCUM! URL
#
# 0  The Tory country first is what   meant. The rest can still suffer austerity that was caused by the rich banks. Parasitic Tories always have been &amp; always will be. The evil party that is the
#
# 1   your disrespect for those that make real sacrifices to defend our freedom is appalling.   is a punk.
#
# 0 I think  knows what he's doing. It's a lose-lose proposition no matter what he does.  Kind of like being a referee at a dog fight.  I'll reserve judgement until Monday. I definitely see where you're coming from.  #MAGA #KAG2018 #KavanaughConfirmation URL
#
# 0   4 he is poor
#
# 0  YAY - AWESOME 🇺🇸♥️😎👈👍MAGA🇺🇸♥️🇺🇸RepPowerVote♥️🇺🇸strengthened by PowerPrayers🇺🇸👍Red Tsunami♥️
#
# 0 #Quebec #election: #Liberals promise more #money to buy #electric cars URL
#
# 0  She was drunk, this rape is her fault."  "He was drunk, this rape isn't his fault.  Said no one, except the crying liberals making more stuff up. You guys are laughable."
#
# 1  Turn them loose and see what happens to her city. People like her is what gives the Democrats a bad name. She is risking the entire population of Atlanta. Wonder how the citizens like it. We’ll see at the ballot box
#
# 1   Good god woman. Shut up. If you liberals really believed this  would have spoke out against this the day she received the letter.
#
# 0  Doesnt bother me.  I will always believe there was more to that story and the father had a part in it some how.
#
# 0  She is selling her pucker nationally
#
# 1  He should not have a job after this. But I guess he is the “lap” dog of some bigwig in broadcasting.
#
# 1  The truth for the gun control/anti-2A URL
#
# 1  Just look at the ass and keep it moving 🤦🏽‍♀️
#
# 0     Jonathan Haidt's The Righteous Mind" should be required reading in high school.  Parts of the book elucidate exactly the problem conservatives like Shapiro contend with: they think everyone thinks/acts like they believe they do - making choices rationally and on principle."
#
# 0  Yeah I bought sumn from them. Tired of morphe 🙄
#
# 0  she is
#
# 0     Libertarian: weed smoking conservatives who let women make their own choices. Hmmm sounds good to me. Almost a modern take on an aging Conservative party.
#
# 0  Patty. You are injury prone like me. 😅
#
# 1  Those liberals are kinky people
#
# 1     Gun control is never sensible.
#
# 1 #WhatILearnedToday  Liberals are the scum of the earth   Absolute treason.
#
# 0   They’re doing it deliberately get rid of the minions problem solved they couldn’t give a monkeys.
#
# 1  Top 5 excuses" liberals use when they are losing and desperate. #1 RACISM #2 Sexism #3 Russia #4 Guns #5 the Rich VOTE DEMOCRATS OUT! America doesn't need LOSER leaders. and WHINERS!"
#
# 1   Liberals  wouldn’t know the first thing about “doing the right thing” 🤣🤣🤣🖕🏼🖕🏼🖕🏼🖕🏼🖕🏼
#
# 0 - Man of Steel: Ok - Batman v Superman: Ok - Suicide Squad: Boring - Justice League: Bad  😔 🤦‍♂️   Reboot. Keep Wonder Woman as she is. Do something with time travel or altered timelines or something.
#
# 1 So since Dems want stand on a soapbox over Kavanaugh exactly when  will you be addressing the sexual slush fund covering your backsides #MAGA
#
# 0            He looks familiar....serial female abuser maybe??
#
# 0  Can't a man call his dog without some old bat bitching about it ?
#
# 0    You must like the antifa style guy.  You don't know what a decent moral man looks like.
#
# 0   And she is Canadian 🇨🇦
#
# 0   Real conservatives are stepping up.
#
# 1  🖤 Dyrus you are a fucking worthless braindead scumfuck bastard pile of trash mental dickface that should be gunned down in the street like the degenerate you are🖤
#
# 1  Carter was the worst one term President until h was passed for that title by Oba our first Black Racist President!  Kinda like  a Black Jefferson Davis!
#
# 0 6d/. They won't be able to make it after January! There will be millions HOMELESS and STARVING! You will see a LOT MORE BEGGING on the STREETS. People living in the woods. THIS is so the rich   #Conservatives #Christians #WhiteSupremacists #MAGA #MAGAVeterans #MAGATalk URL
#
# 1   You are pathetic. This has nothing to do with him his dad or the wall or Mexico. This is about Swallwell thinking its ok for liberals to threaten repubs but not the other away around.
#
# 0            I think he's a comrade URL
#
# 1   You defending sex offenders shows you for who you are.  I don't waste my time with your types
#
# 0  She is right.  Liberals do not listen.  It doesn’t matter what the taxpayer wants Trudeau does not listen.  Maybe to Islam but nothing else
#
# 0  Good for you Jimmy... your one pare will offset the 50% plunge their market shares are about to take
#
# 0   Rampant crime? You mean Chicago a dem city that has the highest gun control of the country? Taking credit for a black man? Everything fell or stagnated with Obama. And caging brown families? Clinton Bush and Obama did it to a far worst extent. And thier illegal so whatever.
#
# 1  This whole thing has been a sham from the start!
#
# 0   He is Spartacus!!!!!
#
# 0 . : Jack Dorsey, to his credit, has openly acknowledged that he has a culture within his company that is hostile to conservatives. Now the question is, what is he going to do about it?" URL URL
#
# 1  This isn't ya finest moment hun. Try again once you fix ya shit and knock this tweet away.
#
# 0  I like the way she shows her emotions... She is really a Queen of Hearts....  ...Love you
#
# 0  Drew Carry is a piece of Canadian S/-“
#
# 1  She says no. You are now sad. She then realizes what you might actually mean. She slaps you. She says no. Now you are sad AND your face hurts.
#
# 0  He. Is. Here. For. Her.
#
# 1   Not one for anything to do with RUSSIAN COLLUSION which BTW is not a crime most b4 they knew DT. The ones who copped out only did so 2 save their ass. I'm just curious why none of u self righteous ppl had a problem w/ all HRC &amp; BO crimes lies spying etc? Hypocritical I'd say.
#
# 0   Billionaires making donations to Democrats don't help advance any left wing causes, they simply cause Democrats to act in the interest of billionaires, just like Republicans, regardless of the absurd conspiracy theories Alex Jones and PJW tell liberals" like you."
#
# 0  Leave it to CBC to turn a bad story for the libs into a critical piece on the conservatives
#
# 1  He’s a disgrace to his party and all he claims to stand for. He’s not on the side of conservatives. He just wants to make a name for himself and anybody’s cost.
#
# 1  You’ve lost your mind. That shit is unsanitary af. URL
#
# 0  I believe that Serena would not cheat. Yet even her manager has admitted to breaking the rules. This was not her finest hour. First a temper tantrum then calling the umpire a thief. That crossed the line. She is the one that should apologize.
#
# 1  I mean, the logic" behind their claim means that in the 90's the Liberals felt it was OK for a man to abuse women... that's essentially what they are saying... and that the Conservatives were in the right... right?"
#
# 0 ALSO WHAT'S UP BITCHES I GOT BANGS AND IT WASN'T A MISTAKE I'M SO EXCITED
#
# 1   He is a disgrace he needs to resign or the citizens of Maricopa County need to start a recall.  If he FUBAR’s the General Election that should be it. No waiting until 2020.
#
# 0  Don't know who he is and don't really care...
#
# 0    She is more influential so many Japanese and British acts are influenced by her? Why do so many foreign acts work with her producers? Why does she have touring records in Europe and Japan?  Why did she win the Legend Award at the WMAs
#
# 0  I didn’t recognise her without her Antifa bandana.
#
# 0     She is a cop.... “gun control” wouldn’t have mattered. Geez
#
# 0       so stronger gun control is better than leaving guns easy to access. Gun control isn't a gun ban 💀
#
# 0  You are welcome dear 😇😇 but for what? URL
#
# 0  This is an excellent way for Antifa members to take the room temperature challenge.
#
# 0                  Is that a bar where antifa sharpens their stones and buys their silly string?
#
# 0   As I’m sure he is advising everyone must evacuate 🙄
#
# 1    You should.have tried more, perhaps a BJP or RSS connection could have been fixed".Masters would be happy Dhanya"
#
# 0 Gee...I wonder? #DrainTheDeepStateSwamp #WWG1WGA #QAnon #MAGA URL
#
# 1  And dying a slow death such a shame
#
# 0   is a DISGRACE to the United States of America!!
#
# 0    Dr. James P. Wickstrom RIP - Gun Control and The Enemy In The Land URL URL
#
# 0  sorry you are feeling sick hope you get better soon.
#
# 0 4 UK/US DEEPSTATE NUKES INTERCEPTED HEADING FOR US CITIES. #skynews #skypapers #bbcdp #lbc #lbclive #talkradio   #altnews #brexit #remain #london #cityoflondon #news #breakingnews #uknews #labour #tories #trump #toryparty #ukip #conservatives #christians #qanon URL
#
# 0 Another win for the common man! #MoreAlligatorGreedAnnulled #MAGA  A federal court has handed a victory to students suing Education Secretary Betsy DeVos over her efforts to dismantle protections against fraud by for-profit colleges. URL
#
# 0   well uk had gun control and were over here fighting for it for the past like 4 years so
#
# 0   Serena was constantly berating the guy between games. Even said he would never work one of her matches again. The third warning was completely justified. She is no saint. Sad such a champion lost her cool so badly
#
# 0  Stay safe you are an inspiration to me. And practice those kung fu skills if they ever show up again :)
#
# 0  Didn't sound bitter to me. The main message was  to recall American values and urge people to quit complaining and vote.
#
# 0        Pretty sure U.S. conservatives are taking cues from this...  Rightwing government wants to make handshake mandatory in naturalisation ceremonies" URL
#
# 0   The last thing parents need to learn from the liberals is the ethics of raising their own child.
#
# 0   You are absolutely right
#
# 0   yes she is!!!!!
#
# 0  That's not Southern California.  It is considered Central California. Great how our gun control laws work here isn't it?
#
# 1  And republicans fall right in line and say these are serious accusations we must postpone the vote until we hear from her".  Many republicans are not interested in being conservatives."
#
# 0  Has this tweet been deleted?
#
# 0        You will never get a straight answer from any gun control group on a question like that!
#
# 1  If anything, wouldn't that be a State Law?  He's running for Federal Office.   thinks Texans are morons...about this and illegally claiming to be a government office and sending out summons" for money. #maga #Texans"
#
# 0 *She is currently helping a customer out on a potion to help with mane loss.* (
#
# 0 ...or that he is merely a 'legacy Colonel'" URL
#
# 0 6 Reason?   There are more. URL
#
# 0  Thank You Chase😘 I miss you more than anything but I know you are where your supposed to be! Love you too the moon😘
#
# 1   You need to look at your Twitter feed a little bit closer. I'm neither a Republican or a racist but that's the only thing that liberals can say about people who don't agree with them. As far as Hillary Clinton the evidence is already been presented but Obama gave her a pass
#
# 1  City of 1 499 900 people who don't fuck" doesn't have quite the same ring to it"
#
# 0      He is Crying In his Pic or Tum Hs rhi ho 😡😡
#
# 0   No one is threatening her.  All a ploy for sympathy and further attack on conservatives.
#
# 1  A little note for  -the Bible ( have you ever read that?) says that if the Holy Spirit is in us that we can fight off the devil. You lie and claim that you are holy (no human is holy by the way) so how dare you blame the devil? Your new name is Pope False Prophet"."
#
# 0   I call you a kid bc I’m certain you are one. And bc it seems to annoy you. Should I just sat “I’m joking” and make it all better?
#
# 0        She is. I dont think politics is for her to dabble in.
#
# 0  At least you know your president is not gay Obama
#
# 1   So Victoria's Secret won't sponsor Trump any more. I hope they realize how much of their crap trump has sold for them to Antifa! URL
#
# 1    Says the fat Antifa member
#
# 0   with this useless try hard comedian love preaching hate about  They have so much hate in them for a guy they loved before he was president. Maybe infatuated with the guy. She must dream about him.
#
# 0  Endorse my sandwich!" could catch on as an imprecation, like "Blow me down!" or "Fuck my old boots!"   And don't worry -- Igor is under strict instructions to eschew any virgin who has partaken of GM crops."
#
# 0     Whoa!  Angie!!! Back off that logic!  You're going to confuse the liberals.
#
# 0  Buck up buttercup!
#
# 1  I don't have anymore excuse me what the fuck" memes."
#
# 1   To justify his death to racists &amp; bigots. They're excuse will be well he had weed so he is a criminal &amp; deserved to be murdered. Just wait till the excuses start.
#
# 0  Answer: DiFi and Antifa Democrats have NO sense of decency remaining
#
# 0  How about juxtapositioning that next to all the conservatives who think it shouldn't be investigated at all? Or are you more interested in slanted BS than actual justice? URL
#
# 0 Fisa drops FULL Servers can then be released/introduced?  ALL Horrors finally exposed?  Public made aware? #DarkToLight  House of cards  #Qanon #GreatAwakening #WWG1WGA #IBOR #MAGA #MBGA #WTOBREXIT
#
# 0                                                  Great group I follow all except the top two because they don't follow back😉 Retweeted.
#
# 0  Well if you are so sure this will work... I can hold on to the notebook if it still is available. Plus I can help try and keep the Junko part of your mind away. Apparently being a part of the Blood Tribe makes you naturally good with technology.""
#
# 0   He has been on the take...Ukranian money...he is dirty
#
# 0  Go roger I quit watching anyway nfl is on the way down the people are moving kids to soccer golf tennis shame but kneelers are killing the game
#
# 1  I believe he asked people 2 vote out aishwarya bcos she is mentally unstable n has mood swings
#
# 1    Jokes are funny if the person saying them doesn’t really hate whites and Christians.  That’s a National past time for liberals these days.  Funny stuff...for the Louis Farrakhan crowd.  Racist crap by any barometer.
#
# 1  I thought it was because you weren't very funny and lacked in talent as a comedian.
#
# 0  He'll be replaced. . . . . . . . by another Muslim.
#
# 0   As suspected this is about derailing Judge Kavanaugh’s confirmation because he is a conservative and will adhere to the Constitution and the law. He’s not an activist judge which is what they want.
#
# 1 A 5th columnist always imagines himself as a patriot. That’s how traitors rationalize perfidy. . . Clearly the deep state, the steady state, the swamp, or whatever you wish to call it sees itself as above such nuisances &amp; trivialities as elections." URL #MAGA"
#
# 0                    Followed all Patriots and retweeted
#
# 0    But the judges decision was totally biased as he is a personal friend and university prof of Tory’s.
#
# 1  Because he didn’t do any think Sorry that not true you and Obama screw the American people when ever you could!
#
# 0  He is leaning the wrong way
#
# 0  we don't want socialism. We don't want open borders. We want better gun control laws. We want our immigration laws fixed. The buying power of our dollar has decreased since Trump took office. we want healthcare for everyone but that doesn't mean we want socialism for everything.
#
# 0  skating is WAY better than before. Visually it doesn't looks a ton better, but it runs smoother and crisper" for lack of a better word. I'm curious how 17 and 18 feel now if I revisit them"
#
# 1 A big Thank you" to all these stupid celebrities. Events like this will only serve to help Republicans in 2018 and 2020 elections.  #MAGA    URL
#
# 0  But please get a better barber first.
#
# 0 ..ya commie pinko...#MAGA URL
#
# 1  Gonna boo his ass regardless now
#
# 0 (6) So clearly team conservative is striving to uphold the notion of virtue and ideas and reasonableness" while liberals are completely violating the social contract to score political points. Again, it doesn't work if both sides aren't upholding their end of the bargain!"
#
# 0   Is it being awarded by The Onion?
#
# 1   You been reading Q again, right? That's what Q says. I believe" it too but still... Sessions is virtually invisible. RR is there to stay. He is NOT going anywhere even when the FISA docs released to public. Won't be COVERED AT ALL by the Shitstream media. Nobody will ever know!"
#
# 0  *too disconnected
#
# 1  Hitler would be so proud of David Hogg URL
#
# 0  BS has no clue what comming out her mouth.WRONG
#
# 0   Why do all you liberals insist on trying to control everyone in America? Why do you insist those of us that work hard for our money have to give it to people who don't? Why do all you liberal millionaires keep your millions while forcing me to give away every dime I make?
#
# 1  you are killing me!!! We landed in PHX 30 min early from SAN and have been sitting on tarmac for 40 min. Now officially late looks like I am going to miss my connection to OAK. This sucks!!!!!!!!
#
# 0  Btw When do we get to the dog kennel on the roof of the Station Wagon part? Now That’s Dog Whistling URL
#
# 0   how about charges against Ellison with 911 calls to validate and this was not when 17
#
# 0  You are so wrong. Although I haven't  had a Whopper in 40 years
#
# 0  Preaching to the choir. :) Cannot be repeated often enough though. Yet, in deep red states conservatives"  keep getting elected. Time for a national adjustment. 🤞"
#
# 0  If deGrom was actually as great of a pitcher as you say he is then he'd hit more homeruns.
#
# 0    #SimonSays Jack Viney eats bricks for breakfast 👊  Favourite moment of the game was Melkshams colossal celebration. He is one of our heart and soul players. URL
#
# 0  By arguing a call? The media and you are making it a big deal
#
# 0  Imbibing at F75 if you are around. Love to have a cocktail with you before I head back to Denver tomorrow morn.
#
# 1  He doesn’t want to give anything to POTUS!
#
# 0   John.  You are winning them over one by one.  Be patient.
#
# 0 9. You are cute all the time URL
#
# 0    Yeah sorry girl but he is right if you actually look up the history. They were created in LA to fight back against violence by Bloods/Crypts
#
# 0   Says the one who has one follower and following two.  I stand by my original text.  Demoncraps = COMMUNIST    #EXPOSETHEDEEPSTATE #enemiesofthestate #militarytribunals #MAGA #TRUMP #WalkAway #Q
#
# 0  your ANTIFA army are the dregs of society". I pay taxes."
#
# 0  Conservatives aren’t violent - liberals are.
#
# 0  Good luck on your future endeavors...you are surely going to be missed 😥
#
# 1   I kind of feel like AntiFa are terrorists.but maybe I'm overstating it lol 🤷‍♂️
#
# 0  Top 5 liberal excuses" #1 Racism #2 Sexism #3 Russia #4 Guns #5 Rich It's what liberals do when they are losing and desperate. VOTE DEMOCRATS OUT!"
#
# 1   You know what wasn’t in his apartment after? Him. And that’s the fucking problem.
#
# 1  Holder should be in prison
#
# 0   YOU ARE SO PRETTY OH MY GOODNESS
#
# 0  Big O - you are right - you don't lose to Gabbert
#
# 0  Cue the liberals’ moral shunning of society for a minute; as they take a break from trying to ruin Brett Kavanaugh’s life &amp; humiliating his family.
#
# 0  try meditation and breathing techniques!
#
# 0  She is textbook colonizer
#
# 0   “has been the inspiration for the rise of violent fascism in America?”  He hasn’t really endorsed or been a advocate of antifa though.
#
# 0   YOU ARE WELCOMEEEE! I also love your other song! You deserve an Island :D
#
# 0  girl you are SO beautiful 😩😍
#
# 0 50 miles from Springfield to Worcester March for Gun Control is technically Hillary Clinton since Chinaly Chanvong wears a Wellesley College sweatshirt. Get your facts straight Mark Zuckerberg.
#
# 0        They did have a trial just a separation. Over 500 kids without their parents and lowlifes like you are thrilled about it.
#
# 1  It's kind of like when a mean old woman says that a pretty young one is Ugly and untalented" just because she is washed up and will never look like that again. For one thing it's catty, secondly, it makes her look like a jealous hater and has-been! #Montel"
#
# 0  She is like one of those bag ladies" you see on the street or a bus, mumbling, cursing out loud, talking to herself or anyone that will listen. Please, GO AWAY! URL
#
# 1  Liberals have truly outdone themselves with this stunt. Absolutely disgusting.
#
# 0  You have the love and support from so many people -even if we are just strangers. You are not alone xo
#
# 0 #ThursdayThoughts Hollywood liberals love socialism.   Why don’t these multi-millionaires get of out their multiple mansions and give them to multiple low income families and buy 1 modest home.
#
# 0           The World Wide Phenomenon of Podcasting and MVP of ShitTalking!
# 0  She is the face of the democrat party. She should be locked up for bullying the Republican Party.  She’s rich. Lives in a mansion and her district is in poverty. She’s more like a dictator in her district!!
#
# 1  The ratings are low because of people like you &amp; the other guy making fun of conservatives.. This is one reason why Trump won..  You people just don't get it &amp; pitiful &amp; shameful...
#
# 0 @ MY LRT IM DYDINV G SHE IS BEAUTIFUL
#
# 1   Could anyone expect anything less from a fool like j rubin? Incompetent hair on fire libs cost people their lives and blame it Pres. Trump.
#
# 0   Debate moving on to the streets is a side effect of media/MPs failing to address questions they need to answer &amp; the violence frequently stems from the thuggish #antifa mobs who oppose these issues being aired. What are your answers to questions here? URL
#
# 0  Why are the tweets that Conservatives are retweeting with comments suddenly Unavailable? I cannot see what they’re talking about if the original tweet is no longer available. Anyone else noticing this?
#
# 1      LMAO you are too dumb... forgive my manners but this pile of shiit you just said can give cancer. URL
#
# 1  Screw you and that keep up" shit honestly 😂"
#
# 1 20 Crazy Things Liberals Blame Trump For URL via   Unhinged blame everything on our President.
#
# 0      Most Texans don't take advice from liberals
#
# 1   You’d also know this isn’t about women at all b/c Democrats don’t call for justice for women assaulted by Democrats when there is both evidence of injury &amp; police reports. You’d know Dems only demand conservatives be found guilty upon accusation. You’d know this is all political. URL
#
# 0   Or we can go  's route and NOT believe any accusations levied against conservative because conservatives are such saints.
#
# 0 ...Instead of taking concrete actions to help #reunite #immigrant #children who were separated from their parents, push forward gun control legislation, or work to #repeal the Muslim travel #ban, they did Trump’s bigoted bidding without question." #FamiliesBelongTogether #NoBan"
#
# 1  You will not win. Texas doesn’t need a liberal. Everything liberals touch turns to crap!!
#
# 0   Unreal!  Liberals have completely lost it and will do anything opposing our President!  Very sad!
#
# 0   Absolutely!  We all know the Dems want all the votes coming to them; that is why they are all pushing for it to happen.  Dems/Liberals are plainly UnAmerican. All they care about is their paycheck and their position. 1st We need term minutes; no more than 2 terms like POTUS has.
#
# 0   Hi Bernice 😊 I hope you are enjoying the #xrpcommunity and learning lots about #xrp 😁 +.0589  💫💥😘
#
# 0           You are so beautiful!!😢😍Xx
#
# 1   Mental case for sure
#
# 0   He won’t!  He’ll do just like Mitch McConnell and never mention the good that  has accomplished.
#
# 0  If we are not in control" then how come you are allowed to tweet that idea in the first place?"
#
# 1  hell yeah it FUCKIG is
#
# 0  Hell ya
#
# 1  Risking his own ass lol
#
# 0   Sure. The far left and Merkel lost faith in him. For indoctrinated Germans on the southpole everything seems north far (right). Maaßen was removed because he called an Antifa-spade a spade. Well, to you promoted" because he spoke up against Merkel &amp; press hysteria. Contradiction"
#
# 0  God that's the one we should have used to remove Holder.
#
# 1  Democ Rats are pulling the Anita Hill trick to derail the Judge Kavanaugh confirmation. It will not work! Get over  triumph. You communists will not destroy the USA #MAGA
#
# 1  He is not a troll he is simply dumb but I’m enjoying it I love tweeter for this 🤣🤣🤣🤣🤣🤣🤣
#
# 0  He is jeopardizing our security!  If he wants to show he favors transparency he can instead  release his taxes!
#
# 0  I'm so sorry for your loss and for everyone blaming you yet it was out of your control. You are still an amazing person keep your head up.
#
# 0   Did he mock a Liberal MP crossing the floor to join the Conservatives because it is evidence that they are basically the same party?
#
# 1  Croatian President's bikini photos worlds hottest president ever URL
#
# 0  you've seen the reports and you might know more than me but have a look at how many businesses have closed down since the coalition of the   and you talk of training people for business.
#
# 1  I found out today that Jesus isn’t white and so now I can’t go to church on Sunday AND I can’t watch football damn Obama liberals
#
# 0   Aweeee happy bday e-panda ♥️♥️ you are an amazing drummer (maybe better than B ;);)) have a great one :))))
#
# 1   Landon sucks I asked him for my birthday if I could play with him but he never got back to me so Landon you suck
#
# 0  Law breakers love these liberals
#
# 0  and  states that she went to save herself from online abuse. If she wants to live in peace then why she is not taking case back and asking relatives to attend hearing.  Contradictory statements and action.
#
# 0  Yes he is!
#
# 0  You are the best. 💜
#
# 1    This is insulting. I'm black and fully capable of getting IDs. What makes you think that we can't?  Lets be honest. This is about liberals (mostly white 1s) that want to appear as saviors and vanguards for minorities. Its about protecting your fraudulent votes.
#
# 0 1/ Here's  as quoted by  factually incorrect on no less than 6 counts: Trump is raising taxes not just on Democrats, he’s raising taxes on  Democrats &amp; Republican &amp; independents &amp; conservatives &amp; short people &amp; tall people.""
#
# 1      She is so calm &amp; patient. That’s great..keep it up. Don’t mind people bc everyone has their own viewpoints on each aspects of life.
#
# 0   Exactly. Hasn’t everyone figured out that the only substantiated threats occur by liberals to conservatives?  The other way around is a farce. Plain and simple. This is made up 💩 to generate sympathy and try to keep a false narrative going.

# %% [markdown]
# ### 2.4 Word embeddings

# %%
tweets = tweets_DF['embedding'].values
tweets = np.array([np.array(t) for t in tweets]).reshape(-1, 100)
y = tweets_DF['label'].values

X_train_embedding, X_test_embedding, y_train, y_test = train_test_split(tweets, y, test_size=0.25, random_state=1000)

# %%
classifier_embedding = LogisticRegression(max_iter=1000)
classifier_embedding.fit(X_train_embedding, y_train)
score = classifier_embedding.score(X_test_embedding, y_test)

print("Accuracy:", score)
# Out:
# Accuracy: 0.6709969788519637

# %% [markdown]
# ---------------------------------
# ## 3. Testing correlation
# __Tested correlation of some features and labels__

# %%
y_pred = tweets_DF['label'].values
y_negative_words = tweets_DF['negative_words'].values
y_negative_sentiment = tweets_DF['negative_sentiment'].values
y_negative_sentiment = [1 if neg > 0  else 0 for neg in y_negative_sentiment]

print("Tweet contains negative word: ", matthews_corrcoef(y_pred, y_negative_words))
print("Tweet has some negative sentiment: ", matthews_corrcoef(y_pred, y_negative_sentiment))
# Out:
# Tweet contains negative word:  0.34682702160710294
# Tweet has some negative sentiment:  0.302094438701342

# %% [markdown]
# ## TODO
# https://docs.google.com/document/d/1OdniS8GEYwaFJy_zNC5GpXkceuGxmOtPK_dV9QAecho/edit

# %% [markdown]
# ----------------------------

# %% [markdown]
# ---------------------
