# %% [markdown]
# # Inspect the OLID dataset
#
# This notebook:
# - inspect data a little bit
# - convert categorical labels to {0,1} labels
# - save train and test data to .csv files

# %%
# Imports

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 1. Load Training Data

# %%
data = pd.read_csv('../Dataset-OLID/OLIDv1.0/olid-training-v1.0.tsv', sep='\t')
data.head(10)
# Out:
#       id                                              tweet subtask_a  \
# 0  86426  @USER She should ask a few native Americans wh...       OFF
# 1  90194  @USER @USER Go home you’re drunk!!! @USER #MAG...       OFF
# 2  16820  Amazon is investigating Chinese employees who ...       NOT
# 3  62688  @USER Someone should'veTaken" this piece of sh...       OFF
# 4  43605  @USER @USER Obama wanted liberals &amp; illega...       NOT
# 5  97670                  @USER Liberals are all Kookoo !!!       OFF
# 6  77444                   @USER @USER Oh noes! Tough shit.       OFF
# 7  52415  @USER was literally just talking about this lo...       OFF
# 8  45157                         @USER Buy more icecream!!!       NOT
# 9  13384  @USER Canada doesn’t need another CUCK! We alr...       OFF
#
#   subtask_b subtask_c
# 0       UNT       NaN
# 1       TIN       IND
# 2       NaN       NaN
# 3       UNT       NaN
# 4       NaN       NaN
# 5       TIN       OTH
# 6       UNT       NaN
# 7       TIN       GRP
# 8       NaN       NaN
# 9       TIN       IND

# %%
data.shape
# Out:
# (13240, 5)

# %%
dataA = data.drop(["subtask_b", "subtask_c"], axis=1)
dataA.head(10)
# Out:
#       id                                              tweet subtask_a
# 0  86426  @USER She should ask a few native Americans wh...       OFF
# 1  90194  @USER @USER Go home you’re drunk!!! @USER #MAG...       OFF
# 2  16820  Amazon is investigating Chinese employees who ...       NOT
# 3  62688  @USER Someone should'veTaken" this piece of sh...       OFF
# 4  43605  @USER @USER Obama wanted liberals &amp; illega...       NOT
# 5  97670                  @USER Liberals are all Kookoo !!!       OFF
# 6  77444                   @USER @USER Oh noes! Tough shit.       OFF
# 7  52415  @USER was literally just talking about this lo...       OFF
# 8  45157                         @USER Buy more icecream!!!       NOT
# 9  13384  @USER Canada doesn’t need another CUCK! We alr...       OFF

# %% [markdown]
# - **StackOverflow:** [Pandas: convert categories to numbers](https://stackoverflow.com/questions/38088652/pandas-convert-categories-to-numbers)

# %%
dataA.subtask_a = pd.Categorical(dataA.subtask_a)
dataA.head(10)
# Out:
#       id                                              tweet subtask_a
# 0  86426  @USER She should ask a few native Americans wh...       OFF
# 1  90194  @USER @USER Go home you’re drunk!!! @USER #MAG...       OFF
# 2  16820  Amazon is investigating Chinese employees who ...       NOT
# 3  62688  @USER Someone should'veTaken" this piece of sh...       OFF
# 4  43605  @USER @USER Obama wanted liberals &amp; illega...       NOT
# 5  97670                  @USER Liberals are all Kookoo !!!       OFF
# 6  77444                   @USER @USER Oh noes! Tough shit.       OFF
# 7  52415  @USER was literally just talking about this lo...       OFF
# 8  45157                         @USER Buy more icecream!!!       NOT
# 9  13384  @USER Canada doesn’t need another CUCK! We alr...       OFF

# %%
dataA['label_a'] = dataA.subtask_a.cat.codes
dataA.head(10)
# Out:
#       id                                              tweet subtask_a  label_a
# 0  86426  @USER She should ask a few native Americans wh...       OFF        1
# 1  90194  @USER @USER Go home you’re drunk!!! @USER #MAG...       OFF        1
# 2  16820  Amazon is investigating Chinese employees who ...       NOT        0
# 3  62688  @USER Someone should'veTaken" this piece of sh...       OFF        1
# 4  43605  @USER @USER Obama wanted liberals &amp; illega...       NOT        0
# 5  97670                  @USER Liberals are all Kookoo !!!       OFF        1
# 6  77444                   @USER @USER Oh noes! Tough shit.       OFF        1
# 7  52415  @USER was literally just talking about this lo...       OFF        1
# 8  45157                         @USER Buy more icecream!!!       NOT        0
# 9  13384  @USER Canada doesn’t need another CUCK! We alr...       OFF        1

# %% [markdown]
# ## 2. Collect some data info

# %%
print("A not nan:", 1-data.subtask_a.isna().sum()/13240.)
# Out:
# A not nan: 1.0

# %%
dataA_info = dataA.groupby(["subtask_a"]).count()

# %%
dataA_info
# Out:
#              id  tweet  label_a
# subtask_a
# NOT        8840   8840     8840
# OFF        4400   4400     4400

# %%
#dataA_info.columns = ["Total", "Percentage"]

# %%
dataA_info
# Out:
#              id  tweet  label_a
# subtask_a
# NOT        8840   8840     8840
# OFF        4400   4400     4400

# %%
#dataA_info.Percentage = dataA_info.Percentage/dataA_info.Percentage.sum()

# %%
dataA_info
# Out:
#              id  tweet  label_a
# subtask_a
# NOT        8840   8840     8840
# OFF        4400   4400     4400

# %% [markdown]
# ## 3. Loading Testset Level A

# %%
test_tweets = pd.read_csv('../Dataset-OLID/OLIDv1.0/testset-levela.tsv', sep='\t')
test_tweets.head(10)
# Out:
#       id                                              tweet
# 0  15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...
# 1  27014  #ConstitutionDay is revered by Conservatives, ...
# 2  30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...
# 3  13876  #Watching #Boomer getting the news that she is...
# 4  60133  #NoPasaran: Unity demo to oppose the far-right...
# 5  83681           . . . What the fuck did he do this time?
# 6  96874  #RAP is a form of ART! Used to express yoursel...
# 7  65507  @USER Do you get the feeling he is kissing @US...
# 8  78910  5 Tips to Enhance Audience Connection on Faceb...
# 9  46363  #BiggBossTamil janani won the task. She is goi...

# %%
test_labels = pd.read_csv('../Dataset-OLID/OLIDv1.0/labels-levela.csv')
test_labels.head(10)
# Out:
#       id label
# 0  15923   OFF
# 1  27014   NOT
# 2  30530   NOT
# 3  13876   NOT
# 4  60133   OFF
# 5  83681   OFF
# 6  96874   NOT
# 7  65507   OFF
# 8  78910   NOT
# 9  46363   NOT

# %% [markdown]
# - **StackOverflow:** [JOIN two dataframes on common column in python
# ](https://stackoverflow.com/questions/41463119/join-two-dataframes-on-common-column-in-python)

# %%
test_data = pd.merge(test_tweets, test_labels, left_on='id', right_on='id', how='left')
test_data.head(10)
# Out:
#       id                                              tweet label
# 0  15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...   OFF
# 1  27014  #ConstitutionDay is revered by Conservatives, ...   NOT
# 2  30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...   NOT
# 3  13876  #Watching #Boomer getting the news that she is...   NOT
# 4  60133  #NoPasaran: Unity demo to oppose the far-right...   OFF
# 5  83681           . . . What the fuck did he do this time?   OFF
# 6  96874  #RAP is a form of ART! Used to express yoursel...   NOT
# 7  65507  @USER Do you get the feeling he is kissing @US...   OFF
# 8  78910  5 Tips to Enhance Audience Connection on Faceb...   NOT
# 9  46363  #BiggBossTamil janani won the task. She is goi...   NOT

# %%
test_data = test_data.rename(columns={'label':'subtask_a'})
test_data.head(10)
# Out:
#       id                                              tweet subtask_a
# 0  15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...       OFF
# 1  27014  #ConstitutionDay is revered by Conservatives, ...       NOT
# 2  30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...       NOT
# 3  13876  #Watching #Boomer getting the news that she is...       NOT
# 4  60133  #NoPasaran: Unity demo to oppose the far-right...       OFF
# 5  83681           . . . What the fuck did he do this time?       OFF
# 6  96874  #RAP is a form of ART! Used to express yoursel...       NOT
# 7  65507  @USER Do you get the feeling he is kissing @US...       OFF
# 8  78910  5 Tips to Enhance Audience Connection on Faceb...       NOT
# 9  46363  #BiggBossTamil janani won the task. She is goi...       NOT

# %%
test_data.subtask_a = pd.Categorical(test_data.subtask_a)
test_data['label_a'] = test_data.subtask_a.cat.codes
test_data.head(10)
# Out:
#       id                                              tweet subtask_a  label_a
# 0  15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...       OFF        1
# 1  27014  #ConstitutionDay is revered by Conservatives, ...       NOT        0
# 2  30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...       NOT        0
# 3  13876  #Watching #Boomer getting the news that she is...       NOT        0
# 4  60133  #NoPasaran: Unity demo to oppose the far-right...       OFF        1
# 5  83681           . . . What the fuck did he do this time?       OFF        1
# 6  96874  #RAP is a form of ART! Used to express yoursel...       NOT        0
# 7  65507  @USER Do you get the feeling he is kissing @US...       OFF        1
# 8  78910  5 Tips to Enhance Audience Connection on Faceb...       NOT        0
# 9  46363  #BiggBossTamil janani won the task. She is goi...       NOT        0

# %% [markdown]
# ## 4. Save data in csv
#
# - **StackOverflow:** [Writing a pandas DataFrame to CSV file](https://stackoverflow.com/questions/16923281/writing-a-pandas-dataframe-to-csv-file)

# %%
dataA.to_csv("../Dataset-OLID/OLIDv1.0/data_subtask_a.csv")
test_data.to_csv("../Dataset-OLID/OLIDv1.0/test_data_subtask_a.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-22-a88e3c527362> in <module>
#       1 dataA.to_csv("../Dataset-OLID/OLIDv1.0/data_subtask_a.csv")
# ----> 2 test_data.to_csv("../Dataset-OLID/OLIDv1.0/test_data_subtask_a.csv")
#
# c:\users\kcava\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# c:\users\kcava\appdata\local\programs\python\python37\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# c:\users\kcava\appdata\local\programs\python\python37\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: '../Dataset-OLID/OLIDv1.0/test_data_subtask_a.csv'

# %% [markdown]
# ## 5. Test data

# %%
train_data = pd.read_csv("../Dataset-OLID/OLIDv1.0/data_subtask_a.csv")
test_data = pd.read_csv("../Dataset-OLID/OLIDv1.0/test_data_subtask_a.csv")

# %%
train_data.head()
# Out:
#    Unnamed: 0     id                                              tweet  \
# 0           0  86426  @USER She should ask a few native Americans wh...
# 1           1  90194  @USER @USER Go home you’re drunk!!! @USER #MAG...
# 2           2  16820  Amazon is investigating Chinese employees who ...
# 3           3  62688  @USER Someone should'veTaken" this piece of sh...
# 4           4  43605  @USER @USER Obama wanted liberals &amp; illega...
#
#   subtask_a  label_a
# 0       OFF        1
# 1       OFF        1
# 2       NOT        0
# 3       OFF        1
# 4       NOT        0

# %%
test_data.head()
# Out:
#    Unnamed: 0     id                                              tweet  \
# 0           0  15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...
# 1           1  27014  #ConstitutionDay is revered by Conservatives, ...
# 2           2  30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...
# 3           3  13876  #Watching #Boomer getting the news that she is...
# 4           4  60133  #NoPasaran: Unity demo to oppose the far-right...
#
#   subtask_a  label_a
# 0       OFF        1
# 1       NOT        0
# 2       NOT        0
# 3       NOT        0
# 4       OFF        1

# %%
len(train_data)
# Out:
# 13240

# %%
len(test_data)
# Out:
# 860
